# %%
import pandas as pd

# %%
csv1 = pd.read_csv("plastic_generation.csv", sep=';')
csv1.head()
# Out:
#    TIME                               GEO (Labels) Plastic wastes
# 0  2004  European Union - 27 countries (from 2020)        9540000
# 1  2004  European Union - 28 countries (2013-2020)       11580000
# 2  2004                                    Belgium        1332559
# 3  2004                                   Bulgaria          44246
# 4  2004                                    Czechia         169315

# %%
csv2 = pd.read_csv("plastic_treatment.csv", sep=';')
csv2.head()
# Out:
#                                 GEO (Labels)  TIME  \
# 0  European Union - 27 countries (from 2020)  2004
# 1  European Union - 27 countries (from 2020)  2006
# 2  European Union - 27 countries (from 2020)  2008
# 3  European Union - 27 countries (from 2020)  2010
# 4  European Union - 27 countries (from 2020)  2012
#
#   Disposal - landfill and other (D1-D7, D12)  \
# 0                                          :
# 1                                          :
# 2                                          :
# 3                                     940000
# 4                                    1250000
#
#   Disposal - landfill (D1, D5, D12) Disposal - incineration (D10)  \
# 0                                 :                             :
# 1                                 :                             :
# 2                                 :                             :
# 3                            930000                        120000
# ...

# %%
merged_data = csv1.merge(csv2,on=["TIME","GEO (Labels)"])
merged_data.head()
# Out:
#    TIME                               GEO (Labels) Plastic wastes  \
# 0  2004  European Union - 27 countries (from 2020)        9540000
# 1  2004  European Union - 28 countries (2013-2020)       11580000
# 2  2004                                    Belgium        1332559
# 3  2004                                   Bulgaria          44246
# 4  2004                                    Czechia         169315
#
#   Disposal - landfill and other (D1-D7, D12)  \
# 0                                          :
# 1                                          :
# 2                                          :
# 3                                          :
# 4                                          :
#
#   Disposal - landfill (D1, D5, D12) Disposal - incineration (D10)  \
# 0                                 :                             :
# 1                                 :                             :
# 2                                 :                             :
# ...

# %%
from google.colab import files
merged_data.to_csv('merged_data.csv')
files.download('merged_data.csv')
